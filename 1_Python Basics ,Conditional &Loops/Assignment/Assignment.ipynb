# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
diameter = int(input("Enter the diameter of the sphere : "))
volume = (4/3 * (math.pi) * (math.pow((diameter/2),3)))
print("Volume of sphere is : ",volume)
# Out:
# Enter the diameter of the sphere : 35
# Volume of sphere is :  22449.297503777063

# %%
first_name , last_name  = input("Enter your name : ").split(" ")

str1 = []
for i in range(1, len(first_name) + 1):
    str1.append(first_name[-i])
    
str1.append(" ")

for i in range(1, len(last_name) + 1):
    str1.append(last_name[-i])

print("".join(str1))
# Out:
# Enter your name : Prashanth S
# htnahsarP S
