# %%
Pandas-profiling , Sweetviz ,
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-12511186b5b6> in <module>
# ----> 1 Pandas-profiling , Sweetviz ,
#
# NameError: name 'Pandas' is not defined

# %%
import dtale
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dtale.show(df)
# Out:
# 2021-04-11 20:58:09,082 - INFO     - NumExpr defaulting to 8 threads.
#         <iframe
#             width="100%"
#             height="475"
#             src="http://PrashanthSingaravelan:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Sweetviz

# %%
import sweetviz as sv

# %%
my_report = sv.analyze(df)
my_report.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## Pandas profiling

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReader(df,title='Pandas Profiling Report')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f740df2820e2> in <module>
# ----> 1 profile = ProfileReader(df,title='Pandas Profiling Report')
#
# NameError: name 'ProfileReader' is not defined

# %% [markdown]
# ## AutoVIZ

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# Out:
# Imported AutoViz_Class. Call by using AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)

# %%
AV = AutoViz_Class()

# %%
AV.AutoViz('diabetes.csv')
# Out:
# Shape of your Data Set: (768, 9)
# Classifying variables in data set...
#     9 Predictors classified...
#         This does not include the Target column(s)
#     No variables removed since no ID or low-information variables found in data set
# Number of All Scatter Plots = 3
# Time to run AutoViz (in seconds) = 3.273
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# ...

# %% [markdown]
# ## Pandas visualization Analysis`

# %%
from pandas_visual_analysis import VisualAnalysis, DataSource

data = DataSource(df)
VisualAnalysis(data)

# %%
VisualAnalysis(df)
